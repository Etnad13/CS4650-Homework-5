# %% [markdown]
# <a href="https://colab.research.google.com/github/Etnad13/CS4650-Homework-5/blob/main/Homework_5_News_API_%2B_Covid_Dataset.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# 	Dante Martinez
# 	3/26/2021
# 	CS 4650.01 – Big Data Analytics and Cloud Computing

# %%
# !pip install spacy
# !pip install newsapi-python
# Out:
# Requirement already satisfied: spacy in /usr/local/lib/python3.7/dist-packages (2.2.4)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in /usr/local/lib/python3.7/dist-packages (from spacy) (2.23.0)
# Requirement already satisfied: catalogue<1.1.0,>=0.0.7 in /usr/local/lib/python3.7/dist-packages (from spacy) (1.0.0)
# Requirement already satisfied: blis<0.5.0,>=0.4.0 in /usr/local/lib/python3.7/dist-packages (from spacy) (0.4.1)
# Requirement already satisfied: wasabi<1.1.0,>=0.4.0 in /usr/local/lib/python3.7/dist-packages (from spacy) (0.8.2)
# Requirement already satisfied: srsly<1.1.0,>=1.0.2 in /usr/local/lib/python3.7/dist-packages (from spacy) (1.0.5)
# Requirement already satisfied: numpy>=1.15.0 in /usr/local/lib/python3.7/dist-packages (from spacy) (1.19.5)
# Requirement already satisfied: plac<1.2.0,>=0.9.6 in /usr/local/lib/python3.7/dist-packages (from spacy) (1.1.3)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /usr/local/lib/python3.7/dist-packages (from spacy) (1.0.5)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.7/dist-packages (from spacy) (54.1.2)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from spacy) (2.0.5)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in /usr/local/lib/python3.7/dist-packages (from spacy) (4.41.1)
# Requirement already satisfied: thinc==7.4.0 in /usr/local/lib/python3.7/dist-packages (from spacy) (7.4.0)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from spacy) (3.0.5)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests<3.0.0,>=2.13.0->spacy) (2.10)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests<3.0.0,>=2.13.0->spacy) (1.24.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests<3.0.0,>=2.13.0->spacy) (2020.12.5)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests<3.0.0,>=2.13.0->spacy) (3.0.4)
# Requirement already satisfied: importlib-metadata>=0.20; python_version < "3.8" in /usr/local/lib/python3.7/dist-packages (from catalogue<1.1.0,>=0.0.7->spacy) (3.7.2)
# Requirement already satisfied: typing-extensions>=3.6.4; python_version < "3.8" in /usr/local/lib/python3.7/dist-packages (from importlib-metadata>=0.20; python_version < "3.8"->catalogue<1.1.0,>=0.0.7->spacy) (3.7.4.3)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata>=0.20; python_version < "3.8"->catalogue<1.1.0,>=0.0.7->spacy) (3.4.1)
# Requirement already satisfied: newsapi-python in /usr/local/lib/python3.7/dist-packages (0.2.6)
# Requirement already satisfied: requests<3.0.0 in /usr/local/lib/python3.7/dist-packages (from newsapi-python) (2.23.0)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests<3.0.0->newsapi-python) (3.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests<3.0.0->newsapi-python) (2020.12.5)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests<3.0.0->newsapi-python) (1.24.3)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests<3.0.0->newsapi-python) (2.10)

# %%
# !python -m spacy download en_core_web_lg
# Out:
# Requirement already satisfied: en_core_web_lg==2.2.5 from https://github.com/explosion/spacy-models/releases/download/en_core_web_lg-2.2.5/en_core_web_lg-2.2.5.tar.gz#egg=en_core_web_lg==2.2.5 in /usr/local/lib/python3.7/dist-packages (2.2.5)
# Requirement already satisfied: spacy>=2.2.2 in /usr/local/lib/python3.7/dist-packages (from en_core_web_lg==2.2.5) (2.2.4)
# Requirement already satisfied: srsly<1.1.0,>=1.0.2 in /usr/local/lib/python3.7/dist-packages (from spacy>=2.2.2->en_core_web_lg==2.2.5) (1.0.5)
# Requirement already satisfied: blis<0.5.0,>=0.4.0 in /usr/local/lib/python3.7/dist-packages (from spacy>=2.2.2->en_core_web_lg==2.2.5) (0.4.1)
# Requirement already satisfied: thinc==7.4.0 in /usr/local/lib/python3.7/dist-packages (from spacy>=2.2.2->en_core_web_lg==2.2.5) (7.4.0)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in /usr/local/lib/python3.7/dist-packages (from spacy>=2.2.2->en_core_web_lg==2.2.5) (4.41.1)
# Requirement already satisfied: numpy>=1.15.0 in /usr/local/lib/python3.7/dist-packages (from spacy>=2.2.2->en_core_web_lg==2.2.5) (1.19.5)
# Requirement already satisfied: catalogue<1.1.0,>=0.0.7 in /usr/local/lib/python3.7/dist-packages (from spacy>=2.2.2->en_core_web_lg==2.2.5) (1.0.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.7/dist-packages (from spacy>=2.2.2->en_core_web_lg==2.2.5) (54.1.2)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in /usr/local/lib/python3.7/dist-packages (from spacy>=2.2.2->en_core_web_lg==2.2.5) (2.23.0)
# Requirement already satisfied: plac<1.2.0,>=0.9.6 in /usr/local/lib/python3.7/dist-packages (from spacy>=2.2.2->en_core_web_lg==2.2.5) (1.1.3)
# Requirement already satisfied: wasabi<1.1.0,>=0.4.0 in /usr/local/lib/python3.7/dist-packages (from spacy>=2.2.2->en_core_web_lg==2.2.5) (0.8.2)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from spacy>=2.2.2->en_core_web_lg==2.2.5) (2.0.5)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /usr/local/lib/python3.7/dist-packages (from spacy>=2.2.2->en_core_web_lg==2.2.5) (1.0.5)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from spacy>=2.2.2->en_core_web_lg==2.2.5) (3.0.5)
# Requirement already satisfied: importlib-metadata>=0.20; python_version < "3.8" in /usr/local/lib/python3.7/dist-packages (from catalogue<1.1.0,>=0.0.7->spacy>=2.2.2->en_core_web_lg==2.2.5) (3.7.2)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests<3.0.0,>=2.13.0->spacy>=2.2.2->en_core_web_lg==2.2.5) (1.24.3)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests<3.0.0,>=2.13.0->spacy>=2.2.2->en_core_web_lg==2.2.5) (2.10)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests<3.0.0,>=2.13.0->spacy>=2.2.2->en_core_web_lg==2.2.5) (3.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests<3.0.0,>=2.13.0->spacy>=2.2.2->en_core_web_lg==2.2.5) (2020.12.5)
# Requirement already satisfied: typing-extensions>=3.6.4; python_version < "3.8" in /usr/local/lib/python3.7/dist-packages (from importlib-metadata>=0.20; python_version < "3.8"->catalogue<1.1.0,>=0.0.7->spacy>=2.2.2->en_core_web_lg==2.2.5) (3.7.4.3)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata>=0.20; python_version < "3.8"->catalogue<1.1.0,>=0.0.7->spacy>=2.2.2->en_core_web_lg==2.2.5) (3.4.1)
# ✔ Download and installation successful
# You can now load the model via spacy.load('en_core_web_lg')

# %%
import spacy
from newsapi import NewsApiClient
nlp_eng = spacy.load('en_core_web_lg')
newsapi = NewsApiClient (api_key='c73902ec702f471abb073ca340f9e62b')

# %%
articles = []

#counter 1 = articles 1-20, counter 5 = 81-100
for counter in range(1,6):
    articles.append(newsapi.get_everything(q='coronavirus', language='en', from_param='2021-02-27', to='2021-03-26', sort_by='relevancy', page=counter))

import pickle

filename = 'articlesCOVID.pckl'
pickle.dump(articles, open(filename, 'wb'))

filename = 'articlesCOVID.pckl'
loaded_model = pickle.load(open(filename, 'rb'))

filepath = '/content/articlesCOVID.pckl'
pickle.dump(loaded_model, open(filepath, 'wb'))

# %%
import pandas as pd

dados = []
for i, article in enumerate(articles):
    for x in article['articles']:
        title = x['title']
        date = x['publishedAt']
        description = x['description']
        content = x['content']
        dados.append({'title':title[0], 'date':date[0], 'desc':description[0], 'content':content})
df = pd.DataFrame(dados)
df = df.dropna()
df.head()
# Out:
#   title date desc                                            content
# 0     C    2    P  But medical ethicists say the list is misleadi...
# 1     C    2    T  Similar laborious efforts may have to be scale...
# 2     C    2    A  What do you think the next few months look lik...
# 3     Y    2    C  Why havent I seen Wayne Knight in the ads for ...
# 4     C    2    I  How is the Green Passport system working, for ...

# %%
for token in doc:
    if ((token.text in nlp_eng.Defaults.stop_words) or (token.text is punctuation)):
        pass
    elif (token.pos_ in pos_tag):
        result.append(token.text)
        return result
    else:
        print("problem")
# Out:
#   File "<ipython-input-92-74b02276361c>", line 6
#     return result
#     ^
# SyntaxError: 'return' outside function

# %%
import wordcloud

text = str(result)
wordcloud = WordCloud(max_font_size=50, max_words=100, background_color="white").generate(text)
plt.figure()
plt.imshow(wordcloud, interpolation="bilinear")
plt.axis("off")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-93-c11536ca0fa5> in <module>()
#       1 import wordcloud
#       2
# ----> 3 text = str(result)
#       4 wordcloud = WordCloud(max_font_size=50, max_words=100, background_color="white").generate(text)
#       5 plt.figure()
#
# NameError: name 'result' is not defined

# %%
object = pd.read_pickle(r'/content/articlesCOVID.pckl')
print(object)
# Out:
# [{'status': 'ok', 'totalResults': 96423, 'articles': [{'source': {'id': None, 'name': 'New York Times'}, 'author': 'Jonathan Wolfe and Amelia Nierenberg', 'title': 'Coronavirus Briefing: What Happened Today', 'description': 'People with underlying conditions are begging officials to add their condition to the vaccine priority list.', 'url': 'https://www.nytimes.com/2021/03/09/us/coronavirus-briefing-what-happened-today.html', 'urlToImage': 'https://static01.nyt.com/images/2021/03/09/multimedia/09coronavirus-nl/09coronavirus-nl-facebookJumbo.png', 'publishedAt': '2021-03-09T23:04:24Z', 'content': 'But medical ethicists say the list is misleading because it suggests that the risks for all medical conditions have been evaluated and ranked. Is a 50-year-old with Type 1 diabetes at higher risk tha… [+1300 chars]'}, {'source': {'id': None, 'name': 'New York Times'}, 'author': 'Jonathan Wolfe and Amelia Nierenberg', 'title': 'Coronavirus Briefing: What Happened Today', 'description': 'The U.S. political divide is affecting its vaccine rollout.', 'url': 'https://www.nytimes.com/2021/03/16/us/coronavirus-today.html', 'urlToImage': 'https://static01.nyt.com/images/2021/03/16/reader-center/16coronavirus-nl/16coronavirus-nl-facebookJumbo.png', 'publishedAt': '2021-03-16T22:21:05Z', 'content': 'Similar laborious efforts may have to be scaled up as the country strives for herd immunity, tries to get the economy back on track and seeks a return to a more normal way of life.\r\nVaccines vs. tryp… [+1331 chars]'}, {'source': {'id': None, 'name': 'New York Times'}, 'author': 'Jonathan Wolfe', 'title': 'Coronavirus Briefing: What Happened Today', 'description': 'An optimistic view of the weeks ahead.', 'url': 'https://www.nytimes.com/2021/03/12/us/coronavirus-today.html', 'urlToImage': 'https://static01.nyt.com/images/2021/03/12/multimedia/12coronavirus-nl/12coronavirus-nl-facebookJumbo.png', 'publishedAt': '2021-03-12T23:12:19Z', 'content': 'What do you think the next few months look like in the U.S.?\r\nWhat I think is going to happen is, two months from now, vaccinations are going to be everywhere. The place is just going to be flooded w… [+2846 chars]'}, {'source': {'id': None, 'name': 'New York Times'}, 'author': 'Sopan Deb', 'title': 'Your N.B.A. Coronavirus Questions, Answered', 'description': 'Can fans attend all games? Will players be vaccinated? Was All-Star weekend safe? Read on to find out.', 'url': 'https://www.nytimes.com/2021/03/11/sports/basketball/nba-covid-vaccine-players.html', 'urlToImage': 'https://static01.nyt.com/images/2021/03/11/sports/11nba-virus/11nba-virus-facebookJumbo.jpg', 'publishedAt': '2021-03-11T22:49:26Z', 'content': 'Why havent I seen Wayne Knight in the ads for Space Jam 2?\r\nIm sorry, Mr. Knight. I cant answer that.\r\nRecently, Gov. Greg Abbott, Republican of Texas, ended the states mask mandate and said that all… [+1110 chars]'}, {'source': {'id': None, 'name': 'New York Times'}, 'author': 'Jonathan Wolfe', 'title': 'Coronavirus Briefing: What Happened Today', 'description': 'Israel’s reopening, and  vaccine doses in limbo.', 'url': 'https://www.nytimes.com/2021/03/11/us/coronavirus-briefing-what-happened-today.html', 'urlToImage': 'https://static01.nyt.com/images/2021/03/11/multimedia/11coronavirus-nl/11coronavirus-nl-facebookJumbo.png', 'publishedAt': '2021-03-11T23:32:45Z', 'content': 'How is the Green Passport system working, for example, at restaurants?\r\nSo to sit inside, you have to have the Green Passport, which you download as a government app on your phone and you have to put… [+1866 chars]'}, {'source': {'id': None, 'name': 'New York Times'}, 'author': 'Jonathan Wolfe and Amelia Nierenberg', 'title': 'Coronavirus Briefing: What Happened Today', 'description': 'Europe is struggling with a third wave.', 'url': 'https://www.nytimes.com/2021/03/15/us/coronavirus-today.html', 'urlToImage': 'https://static01.nyt.com/images/2021/03/15/multimedia/15coronavirus-nl/15coronavirus-nl-facebookJumbo.png',  ...
